# %%
import sympy as sym
from IPython.display import display,Math

# %%
x = sym.symbols('x')

# %%
expr = 4 * x > 8

# %%
expr
# Out:
# 4*x > 8

# %%
sym.solve(expr)
# Out:
# (2 < x) & (x < oo)

# %%
# wedge
# \\wedge

# %%
sym.oo
# Out:
# oo

# %%
exp2 = (x -1) * (x + 3) > 0

# %%
exp2
# Out:
# (x - 1)*(x + 3) > 0

# %%
sym.solve(exp2)
# Out:
# ((-oo < x) & (x < -3)) | ((1 < x) & (x < oo))

# %%
a,b,c = sym.symbols('a b c')

# %%
ex = a*x > b**2/c

# %%
ex
# Out:
# a*x > b**2/c

# %%
sym.solve(ex,x)
# Out:
# a*x > b**2/c

# %%
ex3 = 3 * x / 2 + (4 - 5 *x) / 3 <= 2 - 5*(2 - x)/4

# %%
ex3
# Out:
# 4/3 - x/6 <= 5*x/4 - 1/2

# %%
sym.solve(ex3)
# Out:
# (22/17 <= x) & (x < oo)

# %%
22 / 17
# Out:
# 1.2941176470588236
