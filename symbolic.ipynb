# %%
import sympy as sym
sym.init_printing()
from IPython.display import display
import numpy as np

# %%
x,y = sym.symbols('x,y')
x,y
# Out:
# (x, y)

# %%
y + 4
# Out:
# y + 4

# %%
display(x**y)
# Out:
#  y
# x

# %%
print(x**y)
# Out:
# x**y

# %%
display(x/y)
# Out:
# x
# ─
# y

# %%
np.sqrt(2)
# Out:
# 1.4142135623730951

# %%
display(np.sqrt(2))
# Out:
# 1.4142135623730951

# %%
display(sym.sqrt(2))
# Out:
# √2

# %%
display(y * (x**2))
# Out:
#  2
# x ⋅y

# %%
display(sym.sqrt(4)* x)
# Out:
# 2⋅x

# %%
display(sym.sqrt(x)* sym.sqrt(x))
# Out:
# x

# %%
display(y * x**2)
# Out:
#  2
# x ⋅y

# %%
display(sym.sqrt(4) * x)
# Out:
# 2⋅x

# %%
display(sym.sqrt(x) * sym.sqrt(x))
# Out:
# x
