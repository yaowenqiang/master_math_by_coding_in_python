# %%
import sympy as sym
import numpy as np
from IPython.display import display, Math

# %%
from sympy.abc import x,y

# %%
expr1 = x*(4*y)
expr2 = (x*4)*y

# %%
expr1
# Out:
# 4*x*y

# %%
expr1 == expr2
# Out:
# True

# %%
expr1 - expr2
# Out:
# 0

# %%
e1 = 4*x*y
e2 = x*4*y
e3 = y*4*x

# %%
e1.subs({x:3,y:2})
# Out:
# 24

# %%
e2.subs({x:3,y:2})
# Out:
# 24

# %%
e3.subs({x:3,y:2})
# Out:
# 24

# %%
a,b,c,d = sym.symbols('a,b,c,d')
exp5 = (a+b)*(c+d)

# %%
exp5
# Out:
# (a + b)*(c + d)

# %%
sym.expand(exp5)
# Out:
# a*c + a*d + b*c + b*d

# %%
x,y,z,w = sym.symbols('x y z w')

# %%
x = w*(4-w) + 1/w**w*(1+w)
f1 = x*(y+z)
f2 = 3/x + x**2

# %%
f1 * f2
# Out:
# (y + z)*(w*(4 - w) + (w + 1)/w**w)*((w*(4 - w) + (w + 1)/w**w)**2 + 3/(w*(4 - w) + (w + 1)/w**w))

# %%
sym.sympify(f1 * f2)
# Out:
# (y + z)*(w*(4 - w) + (w + 1)/w**w)*((w*(4 - w) + (w + 1)/w**w)**2 + 3/(w*(4 - w) + (w + 1)/w**w))
